# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(12, 12)}, font_scale=1.2)
np.random.seed(0)

# %%
BigMart_Sales_Train= pd.read_excel('D:/ahmed/Data_set/BigMartSalesTrain.xlsx')
BigMart_Sales_Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
BigMart_Sales_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
BigMart_Sales_Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
BigMart_Sales_Train.describe(include="all")
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
BigMart_Sales_Train.sample(20)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4931           NCS53       14.500          Low Fat         0.089960
# 4148           FDF58          NaN          Low Fat         0.009535
# 7423           NCM29       11.500          Low Fat         0.017742
# 4836           FDM40       10.195          Low Fat         0.000000
# 944            FDH10       21.000          Low Fat         0.049264
# 154            FDX20        7.365          Low Fat         0.042560
# 7230           FDW07          NaN          Regular         0.141998
# 3472           FDN08        7.720          Regular         0.088544
# 2294           DRJ23       18.350          Low Fat         0.069745
# 2588           FDM34       19.000          Low Fat         0.067722
# 2087           FDY19       19.750          Low Fat         0.041331
# 7318           FDV16        7.750              reg         0.083269
# 6126           NCY53       20.000          Low Fat         0.058720
# ...

# %%
def  item_fat(weight):
    if (weight <= 5):
        return("low fat")
    elif((weight >=9) & (weight <=11 )):
        return("Regular")
    elif((weight>= 15) & (weight<= 17)):
        return("LF")
    else:
        return("reg")

# %%
BigMart_Sales_Train['item_fat category'] = BigMart_Sales_Train['Item_Weight'].apply(item_fat)
BigMart_Sales_Train['item_fat category']
# Out:
# 0       Regular
# 1           reg
# 2           reg
# 3           reg
# 4           reg
#          ...
# 8518        reg
# 8519        reg
# 8520    Regular
# 8521        reg
# 8522        reg
# Name: item_fat category, Length: 8523, dtype: object

# %%
BigMart_Sales_Train['item_fat category'].value_counts()
# Out:
# reg        6600
# LF          967
# Regular     907
# low fat      49
# Name: item_fat category, dtype: int64

# %%
BigMart_Sales_Train['item_fat category'].describe()
# Out:
# count     8523
# unique       4
# top        reg
# freq      6600
# Name: item_fat category, dtype: object

# %%
sns.countplot(x= BigMart_Sales_Train['item_fat category'])
# Out:
# <AxesSubplot: xlabel='item_fat category', ylabel='count'>

# %%
BigMart_Sales_Train.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4741           FDQ48       14.300          Regular         0.034606
# 2332           FDI21        5.590          Regular         0.056833
# 957            FDO01       21.100          Regular         0.020761
# 6490           FDR01        5.405          Regular         0.053577
# 3028           FDV34       10.695          Regular         0.019124
# 7194           FDS49        9.000          Low Fat         0.079669
# 8045           FDQ57        7.275          Low Fat         0.027991
# 8469           FDQ45          NaN          Regular         0.019114
# 3521           FDV33        9.600          Regular         0.027386
# 12             FDX32       15.100          Regular         0.100014
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4741           Baking Goods   95.9726            OUT017
# 2332            Snack Foods   61.9168            OUT018
# ...

# %%
BigMart_Sales_Train['collection betwwen location and type'] = BigMart_Sales_Train['Outlet_Location_Type'] + BigMart_Sales_Train['Outlet_Type']
BigMart_Sales_Train['collection betwwen location and type']
# Out:
# 0       Tier 1Supermarket Type1
# 1       Tier 3Supermarket Type2
# 2       Tier 1Supermarket Type1
# 3           Tier 3Grocery Store
# 4       Tier 3Supermarket Type1
#                  ...
# 8518    Tier 3Supermarket Type1
# 8519    Tier 2Supermarket Type1
# 8520    Tier 2Supermarket Type1
# 8521    Tier 3Supermarket Type2
# 8522    Tier 1Supermarket Type1
# Name: collection betwwen location and type, Length: 8523, dtype: object

# %%
BigMart_Sales_Train['collection betwwen location and type'].describe()
# Out:
# count                        8523
# unique                          7
# top       Tier 2Supermarket Type1
# freq                         2785
# Name: collection betwwen location and type, dtype: object

# %%
BigMart_Sales_Train['collection betwwen location and type'].value_counts()
# Out:
# Tier 2Supermarket Type1    2785
# Tier 1Supermarket Type1    1860
# Tier 3Supermarket Type3     935
# Tier 3Supermarket Type1     932
# Tier 3Supermarket Type2     928
# Tier 3Grocery Store         555
# Tier 1Grocery Store         528
# Name: collection betwwen location and type, dtype: int64

# %%
sns.countplot(y=BigMart_Sales_Train['collection betwwen location and type'])
# Out:
# <AxesSubplot: xlabel='count', ylabel='collection betwwen location and type'>

# %%
BigMart_Sales_Train.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6721           FDB36        5.465          Regular         0.048802
# 2778           FDZ15       13.100          Low Fat         0.020913
# 5801           FDI15       13.800          Low Fat         0.141353
# 7868           FDS25        6.885          Regular         0.140009
# 5204           FDE17       20.100          Regular         0.054764
# 1988           DRJ13       12.650          Low Fat         0.105265
# 1776           FDX21          NaN          Low Fat         0.148765
# 4507           FDJ21       16.700          Regular         0.038685
# 3982           FDU38       10.800          Low Fat         0.082550
# 79             FDV25        5.905          Low Fat         0.000000
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 6721  Baking Goods  132.1626            OUT017                       2007
# ...

# %%
def size(Outlet_Size):
    if Outlet_Size == 'Small':
        return 'small'
    else:
        return 'medium'

# %%
BigMart_Sales_Train['size'] = BigMart_Sales_Train['Outlet_Size'].apply(size)
BigMart_Sales_Train['size']
# Out:
# 0       medium
# 1       medium
# 2       medium
# 3       medium
# 4       medium
#          ...
# 8518    medium
# 8519    medium
# 8520     small
# 8521    medium
# 8522     small
# Name: size, Length: 8523, dtype: object

# %%
BigMart_Sales_Train['size'].describe()
# Out:
# count       8523
# unique         2
# top       medium
# freq        6135
# Name: size, dtype: object

# %%
BigMart_Sales_Train['size'].value_counts()
# Out:
# medium    6135
# small     2388
# Name: size, dtype: int64

# %%
BigMart_Sales_Train.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3129           FDP48        7.520          Regular         0.044092
# 4327           FDK41       14.300          Low Fat         0.128263
# 4840           DRF13       12.100          Low Fat         0.029903
# 7263           FDD57       18.100          low fat         0.022434
# 2687           NCL53          NaN          Low Fat         0.000000
# 2041           FDU10       10.100          Regular         0.045763
# 3799           FDV52       20.700          Regular         0.121521
# 6136           FDO16        5.480          Low Fat         0.025288
# 20             FDN22       18.850          Regular         0.138190
# 2128           FDX43        5.655          Low Fat         0.085259
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3129           Baking Goods  182.9950            OUT049
# 4327           Frozen Foods   83.4224            OUT017
# ...

# %%
sns.countplot(x=BigMart_Sales_Train['size'])
# Out:
# <AxesSubplot: xlabel='size', ylabel='count'>

# %%
BigMart_Sales_Train['Outlet_Establishment_Year'] = pd.to_datetime(BigMart_Sales_Train['Outlet_Establishment_Year'])
BigMart_Sales_Train['Outlet_Establishment_Year']
# Out:
# 0      1970-01-01 00:00:00.000001999
# 1      1970-01-01 00:00:00.000002009
# 2      1970-01-01 00:00:00.000001999
# 3      1970-01-01 00:00:00.000001998
# 4      1970-01-01 00:00:00.000001987
#                     ...
# 8518   1970-01-01 00:00:00.000001987
# 8519   1970-01-01 00:00:00.000002002
# 8520   1970-01-01 00:00:00.000002004
# 8521   1970-01-01 00:00:00.000002009
# 8522   1970-01-01 00:00:00.000001997
# Name: Outlet_Establishment_Year, Length: 8523, dtype: datetime64[ns]

# %%
BigMart_Sales_Train['BigMart_Sales_Train'] = pd.to_datetime(BigMart_Sales_Train['Outlet_Establishment_Year'], format='%y', errors=("coerce"))
BigMart_Sales_Train['Outlet_Establishment_Year']
# Out:
# 0      1970-01-01 00:00:00.000001999
# 1      1970-01-01 00:00:00.000002009
# 2      1970-01-01 00:00:00.000001999
# 3      1970-01-01 00:00:00.000001998
# 4      1970-01-01 00:00:00.000001987
#                     ...
# 8518   1970-01-01 00:00:00.000001987
# 8519   1970-01-01 00:00:00.000002002
# 8520   1970-01-01 00:00:00.000002004
# 8521   1970-01-01 00:00:00.000002009
# 8522   1970-01-01 00:00:00.000001997
# Name: Outlet_Establishment_Year, Length: 8523, dtype: datetime64[ns]

# %%
BigMart_Sales_Train['Date']= BigMart_Sales_Train['Outlet_Establishment_Year'].dt.date
BigMart_Sales_Train['Year'] = BigMart_Sales_Train['Outlet_Establishment_Year'].dt.year
BigMart_Sales_Train['Year']
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 8518    1970
# 8519    1970
# 8520    1970
# 8521    1970
# 8522    1970
# Name: Year, Length: 8523, dtype: int64

# %%
BigMart_Sales_Train['Date']
# Out:
# 0       1970-01-01
# 1       1970-01-01
# 2       1970-01-01
# 3       1970-01-01
# 4       1970-01-01
#            ...
# 8518    1970-01-01
# 8519    1970-01-01
# 8520    1970-01-01
# 8521    1970-01-01
# 8522    1970-01-01
# Name: Date, Length: 8523, dtype: object

# %%
BigMart_Sales_Train.sample()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7612           FDS40          NaN          Low Fat         0.024546
#
#          Item_Type  Item_MRP Outlet_Identifier     Outlet_Establishment_Year  \
# 7612  Frozen Foods    34.619            OUT019 1970-01-01 00:00:00.000001985
#
#      Outlet_Size Outlet_Location_Type    Outlet_Type  Item_Outlet_Sales  \
# 7612       Small               Tier 1  Grocery Store             36.619
#
#      item_fat category collection betwwen location and type   size  \
# 7612               reg                  Tier 1Grocery Store  small
#
#                BigMart_Sales_Train        Date  Year
# 7612 1970-01-01 00:00:00.000001985  1970-01-01  1970

# %%
BigMart_Sales_Train.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1073           NCI31       20.000          Low Fat         0.081492
# 955            FDV07        9.500          Low Fat         0.000000
# 5739           FDP27        8.155          Low Fat         0.119937
# 4112           NCR05       10.100          Low Fat         0.054621
# 132            NCR53          NaN          Low Fat         0.144338
# 8059           FDQ01       19.700          Regular         0.160951
# 102            FDW57        8.310          Regular         0.115857
# 8193           FDZ10       17.850          Low Fat         0.044533
# 5509           FDB17       13.150          Low Fat         0.061382
# 1537           FDY24        4.880          Regular         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1073                 Others   35.5190            OUT045
# 955   Fruits and Vegetables  110.4228            OUT017
# ...

# %%
BigMart_Sales_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Item_Identifier                       8523 non-null   object
#  1   Item_Weight                           7060 non-null   float64
#  2   Item_Fat_Content                      8523 non-null   object
#  3   Item_Visibility                       8523 non-null   float64
#  4   Item_Type                             8523 non-null   object
#  5   Item_MRP                              8523 non-null   float64
#  6   Outlet_Identifier                     8523 non-null   object
#  7   Outlet_Establishment_Year             8523 non-null   datetime64[ns]
#  8   Outlet_Size                           6113 non-null   object
#  9   Outlet_Location_Type                  8523 non-null   object
# ...

# %%
BigMart_Sales_Train['Outlet_Size']
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
BigMart_Sales_Train['outlit_num'] = BigMart_Sales_Train['Outlet_Identifier'].apply(lambda x: x[4:])
BigMart_Sales_Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
BigMart_Sales_Train.isnull().sum()
# Out:
# Item_Identifier                            0
# Item_Weight                             1463
# Item_Fat_Content                           0
# Item_Visibility                            0
# Item_Type                                  0
# Item_MRP                                   0
# Outlet_Identifier                          0
# Outlet_Establishment_Year                  0
# Outlet_Size                             2410
# Outlet_Location_Type                       0
# Outlet_Type                                0
# Item_Outlet_Sales                          0
# item_fat category                          0
# collection betwwen location and type       0
# size                                       0
# BigMart_Sales_Train                        0
# Date                                       0
# Year                                       0
# outlit_num                                 0
# dtype: int64

# %%
for col in BigMart_Sales_Train.columns:
    pct_missing = np.mean(BigMart_Sales_Train[col].isnull())
    print('{}  -  {}%'.format(col, round(pct_missing*100)))
# Out:
# Item_Identifier  -  0%
# Item_Weight  -  17%
# Item_Fat_Content  -  0%
# Item_Visibility  -  0%
# Item_Type  -  0%
# Item_MRP  -  0%
# Outlet_Identifier  -  0%
# Outlet_Establishment_Year  -  0%
# Outlet_Size  -  28%
# Outlet_Location_Type  -  0%
# Outlet_Type  -  0%
# Item_Outlet_Sales  -  0%
# item_fat category  -  0%
# collection betwwen location and type  -  0%
# size  -  0%
# BigMart_Sales_Train  -  0%
# Date  -  0%
# Year  -  0%
# outlit_num  -  0%

# %%
BigMart_Sales_Train.drop(['Outlet_Size'], axis=1 , inplace= True)

# %%
BigMart_Sales_Train.isnull().sum()
# Out:
# Item_Identifier                            0
# Item_Weight                             1463
# Item_Fat_Content                           0
# Item_Visibility                            0
# Item_Type                                  0
# Item_MRP                                   0
# Outlet_Identifier                          0
# Outlet_Establishment_Year                  0
# Outlet_Location_Type                       0
# Outlet_Type                                0
# Item_Outlet_Sales                          0
# item_fat category                          0
# collection betwwen location and type       0
# size                                       0
# BigMart_Sales_Train                        0
# Date                                       0
# Year                                       0
# outlit_num                                 0
# dtype: int64

# %%
BigMart_Sales_Train['Item_Weight'].fillna(BigMart_Sales_Train['Item_Weight'].median(),inplace=True)
BigMart_Sales_Train['Item_Weight'].median()
# Out:
# 12.6

# %%
BigMart_Sales_Train['Item_Weight'].fillna(BigMart_Sales_Train['Item_Weight'].mean(),inplace=True)
BigMart_Sales_Train['Item_Weight'].mean()
# Out:
# 12.81341957057374

# %%
BigMart_Sales_Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
BigMart_Sales_Train.isnull().sum()
# Out:
# Item_Identifier                         0
# Item_Weight                             0
# Item_Fat_Content                        0
# Item_Visibility                         0
# Item_Type                               0
# Item_MRP                                0
# Outlet_Identifier                       0
# Outlet_Establishment_Year               0
# Outlet_Location_Type                    0
# Outlet_Type                             0
# Item_Outlet_Sales                       0
# item_fat category                       0
# collection betwwen location and type    0
# size                                    0
# BigMart_Sales_Train                     0
# Date                                    0
# Year                                    0
# outlit_num                              0
# dtype: int64

# %%
BigMart_Sales_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Item_Identifier                       8523 non-null   object
#  1   Item_Weight                           8523 non-null   float64
#  2   Item_Fat_Content                      8523 non-null   object
#  3   Item_Visibility                       8523 non-null   float64
#  4   Item_Type                             8523 non-null   object
#  5   Item_MRP                              8523 non-null   float64
#  6   Outlet_Identifier                     8523 non-null   object
#  7   Outlet_Establishment_Year             8523 non-null   datetime64[ns]
#  8   Outlet_Location_Type                  8523 non-null   object
#  9   Outlet_Type                           8523 non-null   object
# ...

# %%
BigMart_Sales_Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales    Year
# count   8523.00000      8523.000000  8523.000000        8523.000000  8523.0
# mean      12.81342         0.066132   140.992782        2181.288914  1970.0
# std        4.22724         0.051598    62.275067        1706.499616     0.0
# min        4.55500         0.000000    31.290000          33.290000  1970.0
# 25%        9.31000         0.026989    93.826500         834.247400  1970.0
# 50%       12.60000         0.053931   143.012800        1794.331000  1970.0
# 75%       16.00000         0.094585   185.643700        3101.296400  1970.0
# max       21.35000         0.328391   266.888400       13086.964800  1970.0

# %%
BigMart_Sales_Train.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 321            FDX36        9.695          Regular         0.128483
# 237            FDB35       12.300          Regular         0.064565
# 1601           FDO09       13.500          Regular         0.125469
# 2413           FDS28        8.180          Regular         0.082868
# 143            NCC30       16.600          Low Fat         0.027622
#
#           Item_Type  Item_MRP Outlet_Identifier     Outlet_Establishment_Year  \
# 321    Baking Goods  223.9404            OUT049 1970-01-01 00:00:00.000001999
# 237   Starchy Foods   92.9804            OUT013 1970-01-01 00:00:00.000001987
# 1601    Snack Foods  264.4910            OUT049 1970-01-01 00:00:00.000001999
# 2413   Frozen Foods   58.5588            OUT017 1970-01-01 00:00:00.000002007
# 143       Household  177.6344            OUT049 1970-01-01 00:00:00.000001999
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')

# %%
BigMart_Sales_Train['size']=imputer.fit_transform(BigMart_Sales_Train[['size']])

# %%
BigMart_Sales_Train['size'].value_counts()
# Out:
# medium    6135
# small     2388
# Name: size, dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()

# %%
for col in ['Item_Outlet_Sales']:
    BigMart_Sales_Train[col] = imputer.fit_transform(BigMart_Sales_Train[[col]])

# %%
BigMart_Sales_Train.isnull().sum()
# Out:
# Item_Identifier                         0
# Item_Weight                             0
# Item_Fat_Content                        0
# Item_Visibility                         0
# Item_Type                               0
# Item_MRP                                0
# Outlet_Identifier                       0
# Outlet_Establishment_Year               0
# Outlet_Location_Type                    0
# Outlet_Type                             0
# Item_Outlet_Sales                       0
# item_fat category                       0
# collection betwwen location and type    0
# size                                    0
# BigMart_Sales_Train                     0
# Date                                    0
# Year                                    0
# outlit_num                              0
# dtype: int64

# %%
sns.boxplot(x=BigMart_Sales_Train['Item_Visibility'])
# Out:
# <AxesSubplot: xlabel='Item_Visibility'>

# %%
sns.stripplot(x=BigMart_Sales_Train['Item_Visibility'],color='black')
# Out:
# <AxesSubplot: xlabel='Item_Visibility'>

# %%
sns.boxplot(x=BigMart_Sales_Train['Item_Visibility'])
sns.stripplot(x=BigMart_Sales_Train['Item_Visibility'],color='black')
# Out:
# <AxesSubplot: xlabel='Item_Visibility'>

# %%
! pip install datasist
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from datasist.structdata import detect_outliers
outliers_indices = detect_outliers(BigMart_Sales_Train, 0, ['Item_Visibility'])
len(outliers_indices)
# Out:
# 144

# %%
BigMart_Sales_Train.drop(outliers_indices,inplace=True)
sns.boxplot(x='Item_Visibility', data=BigMart_Sales_Train)
sns.stripplot(x='Item_Visibility', data=BigMart_Sales_Train, color="black")
# Out:
# <AxesSubplot: xlabel='Item_Visibility'>

# %%
sns.boxplot(x='Item_Visibility', data=BigMart_Sales_Train)
sns.stripplot(x='Item_Visibility', data=BigMart_Sales_Train, color="black")
# Out:
# <AxesSubplot: xlabel='Item_Visibility'>

# %%
outliers_indices = detect_outliers(BigMart_Sales_Train, 0, ['Item_Visibility'])
col_median = BigMart_Sales_Train['Item_Visibility'].median()
BigMart_Sales_Train['Item_Visibility'].iloc[outliers_indices] = col_median
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3204\4138892531.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BigMart_Sales_Train['Item_Visibility'].iloc[outliers_indices] = col_median

# %%
BigMart_Sales_Train['size']
# Out:
# 0       medium
# 1       medium
# 2       medium
# 3       medium
# 4       medium
#          ...
# 8518    medium
# 8519    medium
# 8520     small
# 8521    medium
# 8522     small
# Name: size, Length: 8379, dtype: object

# %%
nominal_column = ['size']

# %%
for nominal_column in nominal_column:
    print(f'Column is: {nominal_column}')
    print(BigMart_Sales_Train[nominal_column].value_counts())
# Out:
# Column is: size
# medium    6068
# small     2311
# Name: size, dtype: int64

# %%
SIZE = pd.get_dummies(BigMart_Sales_Train, columns=['size'], drop_first=True)
SIZE
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...
